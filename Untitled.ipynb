# %%
import FinanceDataReader as fdr  #for kospi200 data
import pandas as pd
import numpy as np
import os
from sklearn.preprocessing import LabelEncoder
import matplotlib.pyplot as plt
from sklearn.preprocessing import minmax_scale
from keras.layers import Input, Dense
from keras.models import Model

# data crawling
from bs4 import BeautifulSoup
import urllib.request as req
# Out:
# Using TensorFlow backend.

# %%
kospi200_dict = {}
kospi200_list = []
kospi200_korean = []
Url = "https://finance.naver.com/sise/entryJongmok.nhn?&page="
for i in range(1,21):
    url = Url + str(i)
    res = req.urlopen(url).read()
    soup = BeautifulSoup(res, "html.parser")

    kospi_list = soup.select("td.ctg")
    for name in kospi_list:
        krx = name.a.get('href')[-6:]
        kospi200_dict[krx] = name.string
        kospi200_list.append(krx)
        kospi200_korean.append(name.string)
        # print('name : ', name.string)
        # print('KRX : ', name.a.get('href')[-6:])

# %%
print(len(kospi200_list))
# Out:
# 200

# %%
train_data = []
tmp = []
for data in kospi200_list:
    tmp = fdr.DataReader(data, '2014-10-01', '2018-09-30').reset_index()['Close'].tolist()
    if len(tmp) != 981:  # fdr 에서 우리금융지주 316140이 데이터가 없음..
        print(data)
        print(len(tmp))
        continue
    tmp = minmax_scale(tmp, axis=0)
    train_data.append(tmp)
# Out:
# 207940
# 461
# 028260
# 927
# 018260
# 951
# 316140
# 0
# 251270
# 338
# 267250
# 340
# 271560
# 299
# 241560
# 455
# 282330
# 196
# 204320
# 979
# 294870
# 74
# 214320
# 785
# 079550
# 733
# 018250
# 128
# 285130
# 179
# 298040
# 52

# %%
train_data= pd.DataFrame(train_data)
train_data
# Out:
#           0         1         2         3         4         5         6    \
# 0    0.049610  0.041249  0.046823  0.052954  0.035117  0.021182  0.022854
# 1    0.296909  0.306973  0.272466  0.272466  0.264558  0.236520  0.229331
# 2    0.026653  0.026261  0.028074  0.015526  0.013196  0.011904  0.009317
# 3    1.000000  0.876812  0.942029  0.905797  0.847826  0.847826  0.855072
# 4    0.687056  0.662988  0.636906  0.618858  0.646942  0.558673  0.590773
# ..        ...       ...       ...       ...       ...       ...       ...
# 179  0.039921  0.039267  0.026832  0.037958  0.025524  0.016361  0.005236
# 180  0.055104  0.039209  0.042035  0.044507  0.037796  0.023667  0.000000
# 181  0.329679  0.382929  0.459671  0.428348  0.461237  0.490995  0.492561
# 182  0.439883  0.419355  0.372434  0.392962  0.395894  0.348974  0.316716
# 183  0.410046  0.422831  0.416438  0.397260  0.404566  0.387215  0.367123
#
#           7         8         9    ...       971       972       973  \
# 0    0.033445  0.032330  0.026756  ...  0.646878  0.632943  0.683110
# 1    0.252336  0.253774  0.278217  ...  0.709561  0.700935  0.746945
# 2    0.013717  0.011255  0.010741  ...  0.739941  0.764919  0.757573
# 3    0.818841  0.804348  0.702899  ...  0.144928  0.130435  0.144928
# 4    0.594780  0.642926  0.648945  ...  0.538611  0.524569  0.538611
# ..        ...       ...       ...  ...       ...       ...       ...
# 179  0.023560  0.072644  0.056283  ...  0.136126  0.147251  0.149215
# 180  0.009184  0.023313  0.012010  ...  0.425998  0.418933  0.420699
# 181  0.448708  0.454973  0.454973  ...  0.014096  0.010180  0.037588
# 182  0.304985  0.281525  0.275660  ...  0.090909  0.093842  0.114370
# 183  0.364384  0.364384  0.368950  ...  0.083105  0.067580  0.066667
#
#           974       975       976       977       978       979       980
# 0    0.663601  0.673356  0.691472  0.722129  0.726310  0.729097  0.699833
# 1    0.739756  0.751258  0.762761  0.767074  0.732566  0.708124  0.680805
# 2    0.791366  0.785488  0.801652  0.773734  0.791366  0.786957  0.775202
# 3    0.130435  0.123188  0.101449  0.137681  0.137681  0.159420  0.144928
# 4    0.534605  0.528585  0.540624  0.540624  0.528585  0.504517  0.510527
# ..        ...       ...       ...       ...       ...       ...       ...
# 179  0.142670  0.147251  0.144634  0.147906  0.151832  0.161649  0.162958
# 180  0.415401  0.415401  0.390675  0.383610  0.397739  0.408336  0.403038
# 181  0.025842  0.016445  0.020360  0.012529  0.018011  0.024276  0.023493
# 182  0.114370  0.126100  0.134897  0.108504  0.140762  0.120235  0.131965
# 183  0.072146  0.078539  0.077626  0.067580  0.063014  0.058447  0.057534
#
# [184 rows x 981 columns]

# %%
# 이거는 나중에 concat하든지 하자
name_col = kospi200_korean
# Out:
# ['삼성전자',
#  'SK하이닉스',
#  '삼성바이오로직스',
#  '셀트리온',
#  '현대차',
#  'NAVER',
#  '현대모비스',
#  'LG화학',
#  '신한지주',
#  'LG생활건강',
#  'SK텔레콤',
#  '삼성물산',
#  'POSCO',
#  'SK',
#  'KB금융',
#  '기아차',
#  '한국전력',
#  '삼성에스디에스',
#  '삼성SDI',
#  'SK이노베이션',
#  '삼성생명',
#  'KT&G',
#  'LG',
#  '카카오',
#  'S-Oil',
#  'LG전자',
#  '엔씨소프트',
#  '삼성화재',
#  '하나금융지주',
#  '아모레퍼시픽',
#  '한국조선해양',
#  '우리금융지주',
#  '삼성전기',
#  '고려아연',
#  '롯데케미칼',
#  '넷마블',
#  'KT',
#  '기업은행',
#  '강원랜드',
#  '웅진코웨이',
#  '한온시스템',
#  'LG유플러스',
#  '아모레G',
#  '현대글로비스',
#  '현대중공업지주',
#  'LG디스플레이',
#  '현대건설',
#  '삼성중공업',
#  '미래에셋대우',
#  'GS',
#  '현대제철',
#  '오리온',
#  '한국타이어앤테크놀로지',
#  '삼성카드',
#  '한미약품',
#  '롯데지주',
#  '한국금융지주',
#  'DB손해보험',
#  '한국가스공사',
#  '한국항공우주',
#  '에스원',
#  '롯데쇼핑',
#  '휠라코리아',
#  'CJ대한통운',
#  'NH투자증권',
#  'CJ제일제당',
#  '삼성엔지니어링',
#  '두산밥캣',
#  '이마트',
#  'BGF리테일',
#  '대림산업',
#  '대우조선해양',
#  '삼성증권',
#  'LG이노텍',
#  '쌍용양회',
#  'GS리테일',
#  '제일기획',
#  '호텔신라',
#  '메리츠종금증권',
#  '한미사이언스',
#  '유한양행',
#  '한화케미칼',
#  '팬오션',
#  'GS건설',
#  'CJ',
#  'KCC',
#  '대한항공',
#  '현대해상',
#  '포스코인터내셔널',
#  '신세계',
#  'BNK금융지주',
#  '금호석유',
#  '현대엘리베이',
#  '오뚜기',
#  '한화생명',
#  '한화에어로스페이스',
#  '하이트진로',
#  '대우건설',
#  '현대미포조선',
#  '한화',
#  '효성',
#  '현대백화점',
#  '한올바이오파마',
#  '일진머티리얼즈',
#  '동서',
#  '대웅제약',
#  '만도',
#  'SKC',
#  'LS',
#  '영원무역',
#  'OCI',
#  '한전KPS',
#  'LS산전',
#  '한샘',
#  '농심',
#  'SK네트웍스',
#  '현대로템',
#  '녹십자',
#  '현대위아',
#  'HDC현대산업개발',
#  'GKL',
#  '신세계인터내셔날',
#  '두산',
#  '이노션',
#  '코오롱인더',
#  '두산인프라코어',
#  '두산중공업',
#  '한국테크놀로지그룹',
#  '금호타이어',
#  '태광산업',
#  '롯데칠성',
#  '롯데정밀화학',
#  '영풍',
#  '현대그린푸드',
#  '에스엘',
#  '한솔케미칼',
#  '현대홈쇼핑',
#  '한국콜마',
#  '오리온홀딩스',
#  '아이에스동서',
#  '영진약품',
#  '종근당',
#  '녹십자홀딩스',
#  '넥센타이어',
#  '부광약품',
#  '휴켐스',
#  '동원F&B',
#  '동원시스템즈',
#  '대덕전자',
#  'SPC삼립',
#  '한전기술',
#  '후성',
#  '대한유화',
#  '동아에스티',
#  'DB하이텍',
#  'LIG넥스원',
#  '대상',
#  '한세실업',
#  '애경산업',
#  '한섬',
#  '쿠쿠홀딩스',
#  'CJ CGV',
#  'HDC',
#  '코스맥스',
#  '롯데하이마트',
#  'S&T모티브',
#  '락앤락',
#  'LG상사',
#  '풍산',
#  '동국제강',
#  '세아베스틸',
#  'JW중외제약',
#  '보령제약',
#  'LF',
#  'SK케미칼',
#  'BGF',
#  '한일현대시멘트',
#  '빙그레',
#  '삼양홀딩스',
#  '세방전지',
#  'LG하우시스',
#  '대교',
#  '동아쏘시오홀딩스',
#  '삼양사',
#  '롯데푸드',
#  '한국단자',
#  '고려제강',
#  '한라홀딩스',
#  'SK디스커버리',
#  '한국쉘석유',
#  '유니드',
#  'AK홀딩스',
#  '남해화학',
#  'JW홀딩스',
#  '일양약품',
#  '동양',
#  '쌍용차',
#  '남양유업',
#  '현대리바트',
#  '효성중공업']

# %%
# # data_length = day length for one sliced data
# # gap_distance = gap of time series data
# data_length = 70
# gap_distance = 7
# data_divided = []
# for i in range(int((len(train_data)-data_length-6)/gap_distance)):
#     data_divided.append(raw[0+i*gap_distance : data_length+i*gap_distance])
# #현재 data_divided는 List타입
# data_divided = pd.DataFrame(data_divided)
# print(data_divided.shape)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-062bae981983> in <module>
#       5 data_divided = []
#       6 for i in range(int((len(train_data)-data_length-6)/gap_distance)):
# ----> 7     data_divided.append(raw[0+i*gap_distance : data_length+i*gap_distance])
#       8 #현재 data_divided는 List타입
#       9 data_divided = pd.DataFrame(data_divided)
#
# NameError: name 'raw' is not defined

# %%
# minmax_scale 함수가 잘 되는지 확인
# abc = fdr.DataReader('005930', '2014-10-01', '2018-09-30').reset_index()['Close'].tolist()
# abc_minmax = minmax_scale(abc, axis=0)

# %%
# plt.plot(abc_minmax)
# plt.show()

# %%
# plt.plot(abc)
# plt.show()

# %%
# define the number of features
ncol = train_data.shape[1]
ncol
# Out:
# 981

# %%
### Define the encoder dimension
encoding_dim = 30

# %%
input_dim = Input(shape = (ncol, ))

# Encoder Layers
encoded1 = Dense(750, activation = 'relu')(input_dim)
encoded2 = Dense(500, activation = 'relu')(encoded1)
encoded3 = Dense(250, activation = 'relu')(encoded2)
encoded4 = Dense(150, activation = 'relu')(encoded3)
encoded5 = Dense(75, activation = 'relu')(encoded4)
encoded6 = Dense(encoding_dim, activation = 'relu')(encoded5)

# Decoder Layers
decoded1 = Dense(75, activation = 'relu')(encoded6)
decoded2 = Dense(150, activation = 'relu')(decoded1)
decoded3 = Dense(250, activation = 'relu')(decoded2)
decoded4 = Dense(500, activation = 'relu')(decoded3)
decoded5 = Dense(750, activation = 'relu')(decoded4)
decoded6 = Dense(ncol, activation = 'sigmoid')(decoded5)

# Combine Encoder and Deocder layers
autoencoder = Model(inputs = input_dim, outputs = decoded6)

# Compile the Model
autoencoder.compile(optimizer = 'adadelta', loss = 'binary_crossentropy')
# Out:
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\envs\require\lib\site-packages\keras\optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\envs\require\lib\site-packages\keras\backend\tensorflow_backend.py:3657: The name tf.log is deprecated. Please use tf.math.log instead.
#
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\envs\require\lib\site-packages\tensorflow\python\ops\nn_impl.py:180: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where

# %%
autoencoder.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         (None, 981)               0
# _________________________________________________________________
# dense_8 (Dense)              (None, 750)               736500
# _________________________________________________________________
# dense_9 (Dense)              (None, 500)               375500
# _________________________________________________________________
# dense_10 (Dense)             (None, 250)               125250
# _________________________________________________________________
# dense_11 (Dense)             (None, 150)               37650
# _________________________________________________________________
# dense_12 (Dense)             (None, 75)                11325
# _________________________________________________________________
# dense_13 (Dense)             (None, 30)                2280
# _________________________________________________________________
# dense_14 (Dense)             (None, 75)                2325
# _________________________________________________________________
# dense_15 (Dense)             (None, 150)               11400
# _________________________________________________________________
# dense_16 (Dense)             (None, 250)               37750
# _________________________________________________________________
# dense_17 (Dense)             (None, 500)               125500
# _________________________________________________________________
# dense_18 (Dense)             (None, 750)               375750
# _________________________________________________________________
# dense_19 (Dense)             (None, 981)               736731
# =================================================================
# Total params: 2,577,961
# Trainable params: 2,577,961
# Non-trainable params: 0
# _________________________________________________________________

# %%
# autoencoder.fit(train_data, train_data, nb_epoch = 10, batch_size = 32, shuffle = False, validation_data = (t_test, X_test))
