# %%
import pandas as pd
import FinanceDataReader as fdr

# Samsung
samsung = fdr.DataReader('068270', '1992-01-01', '2018-10-31')
# LG
lg = fdr.DataReader('066570', '1992-01-01', '2018-10-31')
# 네이버
naver = fdr.DataReader('035420', '1992-01-01', '2018-10-31')
# 카카오
kakao = fdr.DataReader('035720', '1992-01-01', '2018-10-31')
# KOSPI200 ETF
kospi200 = fdr.DataReader('KS200', '1992-01-01', '2018-10-31')

# df = df.rename(columns = {'Column Name': 'New Name'})

# %%
samsung.head()
# Out:
#             Open  High   Low  Close  Volume    Change
# Date
# 2005-07-19  5378  6180  5224   6185  499088       NaN
# 2005-07-20  6171  6171  5255   5259  422688 -0.149717
# 2005-07-21  5179  5283  4597   4609  182685 -0.123598
# 2005-07-22  4695  4695  4438   4481   69921 -0.027772
# 2005-07-25  4411  4776  4411   4539   61036  0.012944

# %%
samsung[:1000].plot(y=['Open','High','Low','Close'])

# %%
samsung1 = fdr.DataReader('068270', '1992-01-01', '2018-10-31')

# %%
df = pd.concat([samsung,naver,lg,kakao,kospi200], axis=1)
# df = pd.concat([d,naver], axis=1)

# %%
df
# Out:
#                 Open      High       Low     Close     Volume    Change  \
# Date
# 1999-11-11       NaN       NaN       NaN       NaN        NaN       NaN
# 1999-11-12       NaN       NaN       NaN       NaN        NaN       NaN
# 1999-11-15       NaN       NaN       NaN       NaN        NaN       NaN
# 1999-11-16       NaN       NaN       NaN       NaN        NaN       NaN
# 1999-11-17       NaN       NaN       NaN       NaN        NaN       NaN
# 1999-11-18       NaN       NaN       NaN       NaN        NaN       NaN
# 1999-11-19       NaN       NaN       NaN       NaN        NaN       NaN
# 1999-11-22       NaN       NaN       NaN       NaN        NaN       NaN
# 1999-11-23       NaN       NaN       NaN       NaN        NaN       NaN
# 1999-11-24       NaN       NaN       NaN       NaN        NaN       NaN
# 1999-11-25       NaN       NaN       NaN       NaN        NaN       NaN
# 1999-11-26       NaN       NaN       NaN       NaN        NaN       NaN
# ...

# %%
# df.plot(y=['Open','High','Low','Close'])
df.plot(y='Close', figsize=(20,20))
